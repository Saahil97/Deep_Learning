# %%
pip install theano
# Out:
# Requirement already satisfied: theano in c:\users\91789\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\91789\anaconda3\lib\site-packages (from theano) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\91789\anaconda3\lib\site-packages (from theano) (1.18.4)
# Requirement already satisfied: scipy>=0.14 in c:\users\91789\anaconda3\lib\site-packages (from theano) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\91789\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\91789\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\91789\anaconda3\lib\site-packages (from keras) (1.0.8)
# Requirement already satisfied: pyyaml in c:\users\91789\anaconda3\lib\site-packages (from keras) (5.1.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\91789\anaconda3\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\91789\anaconda3\lib\site-packages (from keras) (1.18.4)
# Requirement already satisfied: h5py in c:\users\91789\anaconda3\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: scipy>=0.14 in c:\users\91789\anaconda3\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\91789\anaconda3\lib\site-packages (from keras) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the 'C:\Users\91789\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
conda update --all
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\91789\Anaconda3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     anaconda-navigator-1.10.0  |           py37_0         4.9 MB
#     backports.functools_lru_cache-1.6.1|     pyhd3eb1b0_0          12 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     conda-build-3.21.4         |   py37haa95532_0         550 KB
#     xmltodict-0.12.0           |             py_0          14 KB
#     ------------------------------------------------------------
#                                            Total:         5.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   xmltodict          pkgs/main/noarch::xmltodict-0.12.0-py_0
#
# The following packages will be UPDATED:
#
#   anaconda-navigator                           1.9.7-py37_0 --> 1.10.0-py37_0
#   conda-build                                 3.18.9-py37_3 --> 3.21.4-py37haa95532_0
#
# The following packages will be DOWNGRADED:
#
#   backports.functoo~                             1.6.1-py_0 --> 1.6.1-pyhd3eb1b0_0
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#
#
#
# Downloading and Extracting Packages
#
# backports.functools_ | 12 KB     |            |   0%
# backports.functools_ | 12 KB     | ########## | 100%
# backports.functools_ | 12 KB     | ########## | 100%
#
# xmltodict-0.12.0     | 14 KB     |            |   0%
# xmltodict-0.12.0     | 14 KB     | ########## | 100%
# xmltodict-0.12.0     | 14 KB     | ########## | 100%
#
# conda-build-3.21.4   | 550 KB    |            |   0%
# conda-build-3.21.4   | 550 KB    | 2          |   3%
# conda-build-3.21.4   | 550 KB    | 5          |   6%
# conda-build-3.21.4   | 550 KB    | 8          |   9%
# conda-build-3.21.4   | 550 KB    | #1         |  12%
# conda-build-3.21.4   | 550 KB    | ##         |  20%
# conda-build-3.21.4   | 550 KB    | ##3        |  23%
# conda-build-3.21.4   | 550 KB    | ##6        |  26%
# conda-build-3.21.4   | 550 KB    | ##9        |  29%
# conda-build-3.21.4   | 550 KB    | ###2       |  32%
# conda-build-3.21.4   | 550 KB    | ###4       |  35%
# conda-build-3.21.4   | 550 KB    | ####       |  41%
# conda-build-3.21.4   | 550 KB    | ####3      |  44%
# conda-build-3.21.4   | 550 KB    | ####6      |  47%
# conda-build-3.21.4   | 550 KB    | ####9      |  49%
# conda-build-3.21.4   | 550 KB    | #####2     |  52%
# conda-build-3.21.4   | 550 KB    | #####5     |  55%
# conda-build-3.21.4   | 550 KB    | ######1    |  61%
# conda-build-3.21.4   | 550 KB    | ######4    |  64%
# conda-build-3.21.4   | 550 KB    | ######6    |  67%
# conda-build-3.21.4   | 550 KB    | ######9    |  70%
# conda-build-3.21.4   | 550 KB    | #######2   |  73%
# conda-build-3.21.4   | 550 KB    | #######5   |  76%
# conda-build-3.21.4   | 550 KB    | #######8   |  79%
# conda-build-3.21.4   | 550 KB    | ########1  |  81%
# conda-build-3.21.4   | 550 KB    | ########4  |  84%
# conda-build-3.21.4   | 550 KB    | ########7  |  87%
# conda-build-3.21.4   | 550 KB    | #########  |  90%
# conda-build-3.21.4   | 550 KB    | #########3 |  93%
# conda-build-3.21.4   | 550 KB    | #########6 |  96%
# conda-build-3.21.4   | 550 KB    | #########8 |  99%
# conda-build-3.21.4   | 550 KB    | ########## | 100%
# conda-build-3.21.4   | 550 KB    | ########## | 100%
#
# backports.tempfile-1 | 11 KB     |            |   0%
# backports.tempfile-1 | 11 KB     | ########## | 100%
# backports.tempfile-1 | 11 KB     | ########## | 100%
#
# anaconda-navigator-1 | 4.9 MB    |            |   0%
# anaconda-navigator-1 | 4.9 MB    |            |   0%
# anaconda-navigator-1 | 4.9 MB    |            |   1%
# anaconda-navigator-1 | 4.9 MB    |            |   1%
# anaconda-navigator-1 | 4.9 MB    | 1          |   1%
# anaconda-navigator-1 | 4.9 MB    | 1          |   2%
# anaconda-navigator-1 | 4.9 MB    | 2          |   2%
# anaconda-navigator-1 | 4.9 MB    | 2          |   3%
# anaconda-navigator-1 | 4.9 MB    | 2          |   3%
# anaconda-navigator-1 | 4.9 MB    | 3          |   3%
# anaconda-navigator-1 | 4.9 MB    | 3          |   3%
# anaconda-navigator-1 | 4.9 MB    | 4          |   4%
# anaconda-navigator-1 | 4.9 MB    | 4          |   4%
# anaconda-navigator-1 | 4.9 MB    | 4          |   5%
# anaconda-navigator-1 | 4.9 MB    | 5          |   5%
# anaconda-navigator-1 | 4.9 MB    | 5          |   6%
# anaconda-navigator-1 | 4.9 MB    | 6          |   6%
# anaconda-navigator-1 | 4.9 MB    | 6          |   7%
# anaconda-navigator-1 | 4.9 MB    | 6          |   7%
# anaconda-navigator-1 | 4.9 MB    | 7          |   7%
# anaconda-navigator-1 | 4.9 MB    | 7          |   8%
# anaconda-navigator-1 | 4.9 MB    | 7          |   8%
# anaconda-navigator-1 | 4.9 MB    | 8          |   8%
# anaconda-navigator-1 | 4.9 MB    | 8          |   9%
# anaconda-navigator-1 | 4.9 MB    | 8          |   9%
# anaconda-navigator-1 | 4.9 MB    | 9          |   9%
# anaconda-navigator-1 | 4.9 MB    | 9          |  10%
# anaconda-navigator-1 | 4.9 MB    | 9          |  10%
# anaconda-navigator-1 | 4.9 MB    | #          |  10%
# anaconda-navigator-1 | 4.9 MB    | #          |  10%
# anaconda-navigator-1 | 4.9 MB    | #          |  11%
# anaconda-navigator-1 | 4.9 MB    | #1         |  11%
# anaconda-navigator-1 | 4.9 MB    | #1         |  11%
# anaconda-navigator-1 | 4.9 MB    | #1         |  12%
# anaconda-navigator-1 | 4.9 MB    | #2         |  12%
# anaconda-navigator-1 | 4.9 MB    | #2         |  12%
# anaconda-navigator-1 | 4.9 MB    | #2         |  13%
# anaconda-navigator-1 | 4.9 MB    | #2         |  13%
# anaconda-navigator-1 | 4.9 MB    | #3         |  13%
# anaconda-navigator-1 | 4.9 MB    | #3         |  14%
# anaconda-navigator-1 | 4.9 MB    | #3         |  14%
# anaconda-navigator-1 | 4.9 MB    | #4         |  14%
# anaconda-navigator-1 | 4.9 MB    | #4         |  15%
# anaconda-navigator-1 | 4.9 MB    | #4         |  15%
# anaconda-navigator-1 | 4.9 MB    | #5         |  15%
# anaconda-navigator-1 | 4.9 MB    | #5         |  16%
# anaconda-navigator-1 | 4.9 MB    | #5         |  16%
# anaconda-navigator-1 | 4.9 MB    | #6         |  16%
# anaconda-navigator-1 | 4.9 MB    | #6         |  16%
# anaconda-navigator-1 | 4.9 MB    | #6         |  17%
# anaconda-navigator-1 | 4.9 MB    | #7         |  17%
# anaconda-navigator-1 | 4.9 MB    | #7         |  17%
# anaconda-navigator-1 | 4.9 MB    | #7         |  18%
# anaconda-navigator-1 | 4.9 MB    | #8         |  18%
# anaconda-navigator-1 | 4.9 MB    | #8         |  18%
# anaconda-navigator-1 | 4.9 MB    | #8         |  19%
# anaconda-navigator-1 | 4.9 MB    | #9         |  19%
# anaconda-navigator-1 | 4.9 MB    | #9         |  19%
# anaconda-navigator-1 | 4.9 MB    | #9         |  20%
# anaconda-navigator-1 | 4.9 MB    | #9         |  20%
# anaconda-navigator-1 | 4.9 MB    | ##         |  20%
# anaconda-navigator-1 | 4.9 MB    | ##         |  21%
# anaconda-navigator-1 | 4.9 MB    | ##         |  21%
# anaconda-navigator-1 | 4.9 MB    | ##1        |  21%
# anaconda-navigator-1 | 4.9 MB    | ##1        |  22%
# anaconda-navigator-1 | 4.9 MB    | ##1        |  22%
# anaconda-navigator-1 | 4.9 MB    | ##2        |  22%
# anaconda-navigator-1 | 4.9 MB    | ##2        |  22%
# anaconda-navigator-1 | 4.9 MB    | ##2        |  23%
# anaconda-navigator-1 | 4.9 MB    | ##3        |  23%
# anaconda-navigator-1 | 4.9 MB    | ##3        |  23%
# anaconda-navigator-1 | 4.9 MB    | ##3        |  24%
# anaconda-navigator-1 | 4.9 MB    | ##4        |  24%
# anaconda-navigator-1 | 4.9 MB    | ##4        |  24%
# anaconda-navigator-1 | 4.9 MB    | ##4        |  25%
# anaconda-navigator-1 | 4.9 MB    | ##5        |  25%
# anaconda-navigator-1 | 4.9 MB    | ##5        |  25%
# anaconda-navigator-1 | 4.9 MB    | ##5        |  26%
# anaconda-navigator-1 | 4.9 MB    | ##5        |  26%
# anaconda-navigator-1 | 4.9 MB    | ##6        |  26%
# anaconda-navigator-1 | 4.9 MB    | ##6        |  27%
# anaconda-navigator-1 | 4.9 MB    | ##6        |  27%
# anaconda-navigator-1 | 4.9 MB    | ##7        |  27%
# anaconda-navigator-1 | 4.9 MB    | ##7        |  28%
# anaconda-navigator-1 | 4.9 MB    | ##7        |  28%
# anaconda-navigator-1 | 4.9 MB    | ##8        |  28%
# anaconda-navigator-1 | 4.9 MB    | ##8        |  29%
# anaconda-navigator-1 | 4.9 MB    | ##8        |  29%
# anaconda-navigator-1 | 4.9 MB    | ##9        |  29%
# anaconda-navigator-1 | 4.9 MB    | ##9        |  29%
# anaconda-navigator-1 | 4.9 MB    | ##9        |  30%
# anaconda-navigator-1 | 4.9 MB    | ###        |  30%
# anaconda-navigator-1 | 4.9 MB    | ###        |  30%
# anaconda-navigator-1 | 4.9 MB    | ###        |  31%
# anaconda-navigator-1 | 4.9 MB    | ###1       |  31%
# anaconda-navigator-1 | 4.9 MB    | ###1       |  31%
# anaconda-navigator-1 | 4.9 MB    | ###1       |  32%
# anaconda-navigator-1 | 4.9 MB    | ###2       |  32%
# anaconda-navigator-1 | 4.9 MB    | ###2       |  32%
# anaconda-navigator-1 | 4.9 MB    | ###2       |  33%
# anaconda-navigator-1 | 4.9 MB    | ###2       |  33%
# anaconda-navigator-1 | 4.9 MB    | ###3       |  33%
# anaconda-navigator-1 | 4.9 MB    | ###3       |  34%
# anaconda-navigator-1 | 4.9 MB    | ###3       |  34%
# anaconda-navigator-1 | 4.9 MB    | ###4       |  34%
# anaconda-navigator-1 | 4.9 MB    | ###4       |  35%
# anaconda-navigator-1 | 4.9 MB    | ###4       |  35%
# anaconda-navigator-1 | 4.9 MB    | ###5       |  35%
# anaconda-navigator-1 | 4.9 MB    | ###5       |  35%
# anaconda-navigator-1 | 4.9 MB    | ###5       |  36%
# anaconda-navigator-1 | 4.9 MB    | ###6       |  36%
# anaconda-navigator-1 | 4.9 MB    | ###6       |  36%
# anaconda-navigator-1 | 4.9 MB    | ###6       |  37%
# anaconda-navigator-1 | 4.9 MB    | ###7       |  37%
# anaconda-navigator-1 | 4.9 MB    | ###7       |  37%
# anaconda-navigator-1 | 4.9 MB    | ###7       |  38%
# anaconda-navigator-1 | 4.9 MB    | ###8       |  38%
# anaconda-navigator-1 | 4.9 MB    | ###8       |  38%
# anaconda-navigator-1 | 4.9 MB    | ###8       |  39%
# anaconda-navigator-1 | 4.9 MB    | ###8       |  39%
# anaconda-navigator-1 | 4.9 MB    | ###9       |  39%
# anaconda-navigator-1 | 4.9 MB    | ###9       |  40%
# anaconda-navigator-1 | 4.9 MB    | ###9       |  40%
# anaconda-navigator-1 | 4.9 MB    | ####       |  40%
# anaconda-navigator-1 | 4.9 MB    | ####       |  41%
# anaconda-navigator-1 | 4.9 MB    | ####       |  41%
# anaconda-navigator-1 | 4.9 MB    | ####1      |  41%
# anaconda-navigator-1 | 4.9 MB    | ####1      |  42%
# anaconda-navigator-1 | 4.9 MB    | ####1      |  42%
# anaconda-navigator-1 | 4.9 MB    | ####2      |  42%
# anaconda-navigator-1 | 4.9 MB    | ####2      |  42%
# anaconda-navigator-1 | 4.9 MB    | ####2      |  43%
# anaconda-navigator-1 | 4.9 MB    | ####3      |  43%
# anaconda-navigator-1 | 4.9 MB    | ####3      |  43%
# anaconda-navigator-1 | 4.9 MB    | ####3      |  44%
# anaconda-navigator-1 | 4.9 MB    | ####4      |  44%
# anaconda-navigator-1 | 4.9 MB    | ####4      |  44%
# anaconda-navigator-1 | 4.9 MB    | ####4      |  45%
# anaconda-navigator-1 | 4.9 MB    | ####4      |  45%
# anaconda-navigator-1 | 4.9 MB    | ####5      |  45%
# anaconda-navigator-1 | 4.9 MB    | ####5      |  46%
# anaconda-navigator-1 | 4.9 MB    | ####5      |  46%
# anaconda-navigator-1 | 4.9 MB    | ####6      |  46%
# anaconda-navigator-1 | 4.9 MB    | ####6      |  47%
# anaconda-navigator-1 | 4.9 MB    | ####6      |  47%
# anaconda-navigator-1 | 4.9 MB    | ####7      |  47%
# anaconda-navigator-1 | 4.9 MB    | ####7      |  48%
# anaconda-navigator-1 | 4.9 MB    | ####7      |  48%
# anaconda-navigator-1 | 4.9 MB    | ####8      |  48%
# anaconda-navigator-1 | 4.9 MB    | ####8      |  48%
# anaconda-navigator-1 | 4.9 MB    | ####8      |  49%
# anaconda-navigator-1 | 4.9 MB    | ####9      |  49%
# anaconda-navigator-1 | 4.9 MB    | ####9      |  49%
# anaconda-navigator-1 | 4.9 MB    | ####9      |  50%
# anaconda-navigator-1 | 4.9 MB    | #####      |  50%
# anaconda-navigator-1 | 4.9 MB    | #####      |  50%
# anaconda-navigator-1 | 4.9 MB    | #####      |  51%
# anaconda-navigator-1 | 4.9 MB    | #####1     |  51%
# anaconda-navigator-1 | 4.9 MB    | #####1     |  51%
# anaconda-navigator-1 | 4.9 MB    | #####1     |  52%
# anaconda-navigator-1 | 4.9 MB    | #####1     |  52%
# anaconda-navigator-1 | 4.9 MB    | #####2     |  52%
# anaconda-navigator-1 | 4.9 MB    | #####2     |  53%
# anaconda-navigator-1 | 4.9 MB    | #####2     |  53%
# anaconda-navigator-1 | 4.9 MB    | #####3     |  53%
# anaconda-navigator-1 | 4.9 MB    | #####3     |  54%
# anaconda-navigator-1 | 4.9 MB    | #####3     |  54%
# anaconda-navigator-1 | 4.9 MB    | #####4     |  54%
# anaconda-navigator-1 | 4.9 MB    | #####4     |  55%
# anaconda-navigator-1 | 4.9 MB    | #####4     |  55%
# anaconda-navigator-1 | 4.9 MB    | #####5     |  55%
# anaconda-navigator-1 | 4.9 MB    | #####5     |  55%
# anaconda-navigator-1 | 4.9 MB    | #####5     |  56%
# anaconda-navigator-1 | 4.9 MB    | #####6     |  56%
# anaconda-navigator-1 | 4.9 MB    | #####6     |  56%
# anaconda-navigator-1 | 4.9 MB    | #####6     |  57%
# anaconda-navigator-1 | 4.9 MB    | #####7     |  57%
# anaconda-navigator-1 | 4.9 MB    | #####7     |  57%
# anaconda-navigator-1 | 4.9 MB    | #####7     |  58%
# anaconda-navigator-1 | 4.9 MB    | #####7     |  58%
# anaconda-navigator-1 | 4.9 MB    | #####8     |  58%
# anaconda-navigator-1 | 4.9 MB    | #####8     |  59%
# anaconda-navigator-1 | 4.9 MB    | #####8     |  59%
# anaconda-navigator-1 | 4.9 MB    | #####9     |  59%
# anaconda-navigator-1 | 4.9 MB    | #####9     |  60%
# anaconda-navigator-1 | 4.9 MB    | #####9     |  60%
# anaconda-navigator-1 | 4.9 MB    | ######     |  60%
# anaconda-navigator-1 | 4.9 MB    | ######     |  61%
# anaconda-navigator-1 | 4.9 MB    | ######     |  61%
# anaconda-navigator-1 | 4.9 MB    | ######1    |  61%
# anaconda-navigator-1 | 4.9 MB    | ######1    |  61%
# anaconda-navigator-1 | 4.9 MB    | ######1    |  62%
# anaconda-navigator-1 | 4.9 MB    | ######2    |  62%
# anaconda-navigator-1 | 4.9 MB    | ######2    |  62%
# anaconda-navigator-1 | 4.9 MB    | ######2    |  63%
# anaconda-navigator-1 | 4.9 MB    | ######3    |  63%
# anaconda-navigator-1 | 4.9 MB    | ######3    |  63%
# anaconda-navigator-1 | 4.9 MB    | ######3    |  64%
# anaconda-navigator-1 | 4.9 MB    | ######4    |  64%
# anaconda-navigator-1 | 4.9 MB    | ######4    |  64%
# anaconda-navigator-1 | 4.9 MB    | ######4    |  65%
# anaconda-navigator-1 | 4.9 MB    | ######4    |  65%
# anaconda-navigator-1 | 4.9 MB    | ######5    |  65%
# anaconda-navigator-1 | 4.9 MB    | ######5    |  66%
# anaconda-navigator-1 | 4.9 MB    | ######5    |  66%
# anaconda-navigator-1 | 4.9 MB    | ######6    |  66%
# anaconda-navigator-1 | 4.9 MB    | ######6    |  67%
# anaconda-navigator-1 | 4.9 MB    | ######6    |  67%
# anaconda-navigator-1 | 4.9 MB    | ######7    |  67%
# anaconda-navigator-1 | 4.9 MB    | ######7    |  67%
# anaconda-navigator-1 | 4.9 MB    | ######7    |  68%
# anaconda-navigator-1 | 4.9 MB    | ######8    |  68%
# anaconda-navigator-1 | 4.9 MB    | ######8    |  68%
# anaconda-navigator-1 | 4.9 MB    | ######8    |  69%
# anaconda-navigator-1 | 4.9 MB    | ######9    |  69%
# anaconda-navigator-1 | 4.9 MB    | ######9    |  69%
# anaconda-navigator-1 | 4.9 MB    | ######9    |  70%
# anaconda-navigator-1 | 4.9 MB    | #######    |  70%
# anaconda-navigator-1 | 4.9 MB    | #######    |  70%
# anaconda-navigator-1 | 4.9 MB    | #######    |  71%
# anaconda-navigator-1 | 4.9 MB    | #######    |  71%
# anaconda-navigator-1 | 4.9 MB    | #######1   |  71%
# anaconda-navigator-1 | 4.9 MB    | #######1   |  72%
# anaconda-navigator-1 | 4.9 MB    | #######1   |  72%
# anaconda-navigator-1 | 4.9 MB    | #######2   |  72%
# anaconda-navigator-1 | 4.9 MB    | #######2   |  73%
# anaconda-navigator-1 | 4.9 MB    | #######2   |  73%
# anaconda-navigator-1 | 4.9 MB    | #######3   |  73%
# anaconda-navigator-1 | 4.9 MB    | #######3   |  74%
# anaconda-navigator-1 | 4.9 MB    | #######3   |  74%
# anaconda-navigator-1 | 4.9 MB    | #######4   |  74%
# anaconda-navigator-1 | 4.9 MB    | #######4   |  74%
# anaconda-navigator-1 | 4.9 MB    | #######4   |  75%
# anaconda-navigator-1 | 4.9 MB    | #######5   |  75%
# anaconda-navigator-1 | 4.9 MB    | #######5   |  75%
# anaconda-navigator-1 | 4.9 MB    | #######5   |  76%
# anaconda-navigator-1 | 4.9 MB    | #######6   |  76%
# anaconda-navigator-1 | 4.9 MB    | #######6   |  76%
# anaconda-navigator-1 | 4.9 MB    | #######6   |  77%
# anaconda-navigator-1 | 4.9 MB    | #######7   |  77%
# anaconda-navigator-1 | 4.9 MB    | #######7   |  78%
# anaconda-navigator-1 | 4.9 MB    | #######7   |  78%
# anaconda-navigator-1 | 4.9 MB    | #######8   |  78%
# anaconda-navigator-1 | 4.9 MB    | #######8   |  79%
# anaconda-navigator-1 | 4.9 MB    | #######8   |  79%
# anaconda-navigator-1 | 4.9 MB    | #######9   |  79%
# anaconda-navigator-1 | 4.9 MB    | #######9   |  80%
# anaconda-navigator-1 | 4.9 MB    | #######9   |  80%
# anaconda-navigator-1 | 4.9 MB    | ########   |  80%
# anaconda-navigator-1 | 4.9 MB    | ########   |  80%
# anaconda-navigator-1 | 4.9 MB    | ########   |  81%
# anaconda-navigator-1 | 4.9 MB    | ########1  |  81%
# anaconda-navigator-1 | 4.9 MB    | ########1  |  81%
# anaconda-navigator-1 | 4.9 MB    | ########1  |  82%
# anaconda-navigator-1 | 4.9 MB    | ########2  |  82%
# anaconda-navigator-1 | 4.9 MB    | ########2  |  82%
# anaconda-navigator-1 | 4.9 MB    | ########2  |  83%
# anaconda-navigator-1 | 4.9 MB    | ########3  |  83%
# anaconda-navigator-1 | 4.9 MB    | ########3  |  83%
# anaconda-navigator-1 | 4.9 MB    | ########3  |  84%
# anaconda-navigator-1 | 4.9 MB    | ########3  |  84%
# anaconda-navigator-1 | 4.9 MB    | ########4  |  85%
# anaconda-navigator-1 | 4.9 MB    | ########5  |  86%
# anaconda-navigator-1 | 4.9 MB    | ########6  |  86%
# anaconda-navigator-1 | 4.9 MB    | ########6  |  87%
# anaconda-navigator-1 | 4.9 MB    | ########7  |  87%
# anaconda-navigator-1 | 4.9 MB    | ########7  |  87%
# anaconda-navigator-1 | 4.9 MB    | ########7  |  88%
# anaconda-navigator-1 | 4.9 MB    | ########8  |  88%
# anaconda-navigator-1 | 4.9 MB    | ########8  |  88%
# anaconda-navigator-1 | 4.9 MB    | ########8  |  89%
# anaconda-navigator-1 | 4.9 MB    | ########9  |  89%
# anaconda-navigator-1 | 4.9 MB    | ########9  |  89%
# anaconda-navigator-1 | 4.9 MB    | ########9  |  90%
# anaconda-navigator-1 | 4.9 MB    | ########9  |  90%
# anaconda-navigator-1 | 4.9 MB    | #########  |  90%
# anaconda-navigator-1 | 4.9 MB    | #########  |  91%
# anaconda-navigator-1 | 4.9 MB    | #########  |  91%
# anaconda-navigator-1 | 4.9 MB    | #########1 |  91%
# anaconda-navigator-1 | 4.9 MB    | #########1 |  92%
# anaconda-navigator-1 | 4.9 MB    | #########2 |  93%
# anaconda-navigator-1 | 4.9 MB    | #########2 |  93%
# anaconda-navigator-1 | 4.9 MB    | #########3 |  93%
# anaconda-navigator-1 | 4.9 MB    | #########3 |  93%
# anaconda-navigator-1 | 4.9 MB    | #########4 |  94%
# anaconda-navigator-1 | 4.9 MB    | #########4 |  95%
# anaconda-navigator-1 | 4.9 MB    | #########5 |  95%
# anaconda-navigator-1 | 4.9 MB    | #########5 |  96%
# anaconda-navigator-1 | 4.9 MB    | #########6 |  96%
# anaconda-navigator-1 | 4.9 MB    | #########6 |  96%
# anaconda-navigator-1 | 4.9 MB    | #########6 |  97%
# anaconda-navigator-1 | 4.9 MB    | #########7 |  97%
# anaconda-navigator-1 | 4.9 MB    | #########7 |  98%
# anaconda-navigator-1 | 4.9 MB    | #########7 |  98%
# anaconda-navigator-1 | 4.9 MB    | #########8 |  98%
# anaconda-navigator-1 | 4.9 MB    | #########8 |  99%
# anaconda-navigator-1 | 4.9 MB    | #########8 |  99%
# anaconda-navigator-1 | 4.9 MB    | #########9 |  99%
# anaconda-navigator-1 | 4.9 MB    | #########9 | 100%
# anaconda-navigator-1 | 4.9 MB    | #########9 | 100%
# anaconda-navigator-1 | 4.9 MB    | ########## | 100%
# anaconda-navigator-1 | 4.9 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# DEBUG menuinst_win32:__init__(199): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\91789\Anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\91789\Anaconda3\pythonw.exe, args are ['C:\\Users\\91789\\Anaconda3\\cwp.py', 'C:\\Users\\91789\\Anaconda3', 'C:\\Users\\91789\\Anaconda3\\pythonw.exe', 'C:\\Users\\91789\\Anaconda3\\Scripts\\anaconda-navigator-script.py']
# DEBUG menuinst_win32:__init__(199): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\91789\Anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\91789\Anaconda3\pythonw.exe, args are ['C:\\Users\\91789\\Anaconda3\\cwp.py', 'C:\\Users\\91789\\Anaconda3', 'C:\\Users\\91789\\Anaconda3\\pythonw.exe', 'C:\\Users\\91789\\Anaconda3\\Scripts\\anaconda-navigator-script.py']
# DEBUG menuinst_win32:__init__(199): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\91789\Anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# DEBUG menuinst_win32:create(323): Shortcut cmd is C:\Users\91789\Anaconda3\pythonw.exe, args are ['C:\\Users\\91789\\Anaconda3\\cwp.py', 'C:\\Users\\91789\\Anaconda3', 'C:\\Users\\91789\\Anaconda3\\pythonw.exe', 'C:\\Users\\91789\\Anaconda3\\Scripts\\anaconda-navigator-script.py']

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# import the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
# X = independent variables
X = dataset.iloc[:, 3:13].values
# y = target variable
y = dataset.iloc[:, 13].values

# %%
#print independent variables
print(X)
# Out:
# [[619 'France' 'Female' ... 1 1 101348.88]
#  [608 'Spain' 'Female' ... 0 1 112542.58]
#  [502 'France' 'Female' ... 1 0 113931.57]
#  ...
#  [709 'France' 'Female' ... 0 1 42085.58]
#  [772 'Germany' 'Male' ... 1 0 92888.52]
#  [792 'France' 'Female' ... 1 0 38190.78]]

# %%
# Encode Categorical data Here it is Country and Name
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])

# %%
print(X)
# All independent variables are of float64 type
# Out:
# [[619 0 0 ... 1 1 101348.88]
#  [608 2 0 ... 0 1 112542.58]
#  [502 0 0 ... 1 0 113931.57]
#  ...
#  [709 0 0 ... 0 1 42085.58]
#  [772 1 1 ... 1 0 92888.52]
#  [792 0 0 ... 1 0 38190.78]]

# %%
X = X[:, 1:]

# %%
# Splitting the dataset into Training and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Building the ANN
import keras 
from keras.models import Sequential
from keras.layers import Dense

# Initializing the ANN
classifier = Sequential()
# Add Input layer and Hidden layer
classifier.add(Dense(output_dim = 6, init='uniform', activation='relu', input_dim=9))
# Add 2nd Hidden layer
classifier.add(Dense(output_dim = 6, init='uniform', activation='relu'))
# Add output layer
classifier.add(Dense(output_dim = 1, init='uniform', activation='sigmoid'))
# Out:
# C:\Users\91789\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", input_dim=9, units=6, kernel_initializer="uniform")`
#   if __name__ == '__main__':
# C:\Users\91789\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=6, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\91789\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1, kernel_initializer="uniform")`
#   del sys.path[0]

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', loss ='binary_crossentropy', metrics=['accuracy'])

# %%
# Fit ANN to training set
classifier.fit(X_train, y_train, batch_size = 10, nb_epoch = 100)
# Out:
# C:\Users\91789\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.4826 - accuracy: 0.7960
# Epoch 2/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4325 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4259 - accuracy: 0.7980
# Epoch 4/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4219 - accuracy: 0.8230
# Epoch 5/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4188 - accuracy: 0.8274
# Epoch 6/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4165 - accuracy: 0.8300
# Epoch 7/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4145 - accuracy: 0.8329
# Epoch 8/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4124 - accuracy: 0.8311
# Epoch 9/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4115 - accuracy: 0.8321
# Epoch 10/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4100 - accuracy: 0.8353
# Epoch 11/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4091 - accuracy: 0.8340
# Epoch 12/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4078 - accuracy: 0.8334
# Epoch 13/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4077 - accuracy: 0.8340
# Epoch 14/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4065 - accuracy: 0.8340
# Epoch 15/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4060 - accuracy: 0.8349
# Epoch 16/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4049 - accuracy: 0.8354
# Epoch 17/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4051 - accuracy: 0.8355
# Epoch 18/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4048 - accuracy: 0.8340
# Epoch 19/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4040 - accuracy: 0.8351
# Epoch 20/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4042 - accuracy: 0.8332
# Epoch 21/100
# 8000/8000 [==============================] - 23s 3ms/step - loss: 0.4033 - accuracy: 0.8351
# Epoch 22/100
# 8000/8000 [==============================] - 17s 2ms/step - loss: 0.4028 - accuracy: 0.8345
# Epoch 23/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4025 - accuracy: 0.8357
# Epoch 24/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4026 - accuracy: 0.8354
# Epoch 25/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4021 - accuracy: 0.8370
# Epoch 26/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4022 - accuracy: 0.8346
# Epoch 27/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4014 - accuracy: 0.8353
# Epoch 28/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4022 - accuracy: 0.8340
# Epoch 29/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4022 - accuracy: 0.8338
# Epoch 30/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4016 - accuracy: 0.8338
# Epoch 31/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4017 - accuracy: 0.8354
# Epoch 32/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4016 - accuracy: 0.8342
# Epoch 33/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4016 - accuracy: 0.8341
# Epoch 34/100
# 8000/8000 [==============================] - 10s 1ms/step - loss: 0.4020 - accuracy: 0.8341
# Epoch 35/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4015 - accuracy: 0.8351
# Epoch 36/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4011 - accuracy: 0.8351
# Epoch 37/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4009 - accuracy: 0.8356
# Epoch 38/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4014 - accuracy: 0.8364
# Epoch 39/100
# 8000/8000 [==============================] - 12s 2ms/step - loss: 0.4013 - accuracy: 0.8347
# Epoch 40/100
# 8000/8000 [==============================] - 12s 2ms/step - loss: 0.4012 - accuracy: 0.8342
# Epoch 41/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4007 - accuracy: 0.8341
# Epoch 42/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4009 - accuracy: 0.8334
# Epoch 43/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4013 - accuracy: 0.8345
# Epoch 44/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4004 - accuracy: 0.8353
# Epoch 45/100
# 8000/8000 [==============================] - 12s 2ms/step - loss: 0.4010 - accuracy: 0.8353
# Epoch 46/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4004 - accuracy: 0.8353
# Epoch 47/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4009 - accuracy: 0.8349
# Epoch 48/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4008 - accuracy: 0.8349
# Epoch 49/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4001 - accuracy: 0.8360
# Epoch 50/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4007 - accuracy: 0.8357
# Epoch 51/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4008 - accuracy: 0.8334
# Epoch 52/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4005 - accuracy: 0.8345
# Epoch 53/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4004 - accuracy: 0.8351
# Epoch 54/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4003 - accuracy: 0.8345
# Epoch 55/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4005 - accuracy: 0.8361
# Epoch 56/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4001 - accuracy: 0.8347
# Epoch 57/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4005 - accuracy: 0.8359
# Epoch 58/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4003 - accuracy: 0.8357
# Epoch 59/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4005 - accuracy: 0.8347
# Epoch 60/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8353
# Epoch 61/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4004 - accuracy: 0.8342
# Epoch 62/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8340
# Epoch 63/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4003 - accuracy: 0.8341
# Epoch 64/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3999 - accuracy: 0.8341
# Epoch 65/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4003 - accuracy: 0.8345
# Epoch 66/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4007 - accuracy: 0.8346
# Epoch 67/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4004 - accuracy: 0.8357
# Epoch 68/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4004 - accuracy: 0.8349
# Epoch 69/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4003 - accuracy: 0.8355
# Epoch 70/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.3998 - accuracy: 0.8351
# Epoch 71/100
# 8000/8000 [==============================] - 12s 1ms/step - loss: 0.4006 - accuracy: 0.8342
# Epoch 72/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3999 - accuracy: 0.8344
# Epoch 73/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8353
# Epoch 74/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3999 - accuracy: 0.8346
# Epoch 75/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4006 - accuracy: 0.8335
# Epoch 76/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8341
# Epoch 77/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3998 - accuracy: 0.8359
# Epoch 78/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4000 - accuracy: 0.8335
# Epoch 79/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4003 - accuracy: 0.8344
# Epoch 80/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8329
# Epoch 81/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4001 - accuracy: 0.8339
# Epoch 82/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3999 - accuracy: 0.8341
# Epoch 83/100
# 8000/8000 [==============================] - 31s 4ms/step - loss: 0.4002 - accuracy: 0.8344
# Epoch 84/100
# 8000/8000 [==============================] - 19s 2ms/step - loss: 0.3995 - accuracy: 0.8354
# Epoch 85/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4000 - accuracy: 0.8349
# Epoch 86/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4000 - accuracy: 0.8344
# Epoch 87/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3995 - accuracy: 0.8342
# Epoch 88/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3997 - accuracy: 0.8355
# Epoch 89/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3997 - accuracy: 0.8342
# Epoch 90/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4001 - accuracy: 0.8356
# Epoch 91/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4000 - accuracy: 0.8354
# Epoch 92/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3998 - accuracy: 0.8340
# Epoch 93/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3998 - accuracy: 0.8355
# Epoch 94/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3997 - accuracy: 0.8354
# Epoch 95/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4004 - accuracy: 0.8339
# Epoch 96/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4001 - accuracy: 0.8342
# Epoch 97/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8339
# Epoch 98/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3993 - accuracy: 0.8340
# Epoch 99/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.4002 - accuracy: 0.8342
# Epoch 100/100
# 8000/8000 [==============================] - 11s 1ms/step - loss: 0.3996 - accuracy: 0.8346

# %%
# Predicting the test set results
y_pred = classifier.predict(X_test)
# Normalizing to True and False
y_pred = (y_pred>0.5)
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1536,   59],
#        [ 260,  145]], dtype=int64)

# %%
# Accuracy on the test set
(1536 + 145)/2000
# Out:
# 0.8405
