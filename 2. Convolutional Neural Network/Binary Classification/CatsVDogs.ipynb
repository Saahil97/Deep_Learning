# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#getting the data
base_dir = 'images'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir,'validation')

# %%
train_cats = os.path.join(train_dir, 'cats')
train_dogs = os.path.join(train_dir, 'dogs')
validation_cats = os.path.join(validation_dir, 'cats')
validation_dogs = os.path.join(validation_dir, 'dogs')

# %%
num_cats_tr = len(os.listdir(train_cats))
num_dogs_tr = len(os.listdir(train_dogs))
num_cats_val = len(os.listdir(validation_cats))
num_dogs_val = len(os.listdir(validation_dogs))

# %%
total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
BATCH_SIZE = 32
IMG_SHAPE = 224

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE, IMG_SHAPE),
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=validation_dir,
                                                           shuffle=False,
                                                           target_size=(IMG_SHAPE, IMG_SHAPE),
                                                           class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
#Model Building
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 3)), # RGB
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Dropout(0.5), 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    
    tf.keras.layers.Dense(2, activation='softmax') 
    
    ])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 4,960,194
# Trainable params: 4,960,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 50

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
    )
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 63/63 [==============================] - 92s 1s/step - loss: 1.3748 - accuracy: 0.4986 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 2/50
# 63/63 [==============================] - 93s 1s/step - loss: 0.6925 - accuracy: 0.5252 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 3/50
# 63/63 [==============================] - 105s 2s/step - loss: 0.6933 - accuracy: 0.5026 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.6931 - accuracy: 0.5069 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 5/50
# 63/63 [==============================] - 105s 2s/step - loss: 0.6932 - accuracy: 0.4886 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/50
# 63/63 [==============================] - 99s 2s/step - loss: 0.6932 - accuracy: 0.4848 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.6932 - accuracy: 0.4942 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 8/50
# 63/63 [==============================] - 105s 2s/step - loss: 0.6932 - accuracy: 0.4928 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 9/50
# 63/63 [==============================] - 106s 2s/step - loss: 0.6932 - accuracy: 0.4852 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 10/50
# 63/63 [==============================] - 107s 2s/step - loss: 0.6932 - accuracy: 0.4954 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 11/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.6931 - accuracy: 0.5062 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 12/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.6932 - accuracy: 0.4802 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 13/50
# 63/63 [==============================] - 100s 2s/step - loss: 0.6932 - accuracy: 0.4893 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/50
# 63/63 [==============================] - 94s 1s/step - loss: 0.6934 - accuracy: 0.4509 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 15/50
# 63/63 [==============================] - 94s 1s/step - loss: 0.6933 - accuracy: 0.4880 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 16/50
# 63/63 [==============================] - 95s 2s/step - loss: 0.6931 - accuracy: 0.4890 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 17/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.6932 - accuracy: 0.4841 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 18/50
# 63/63 [==============================] - 107s 2s/step - loss: 0.6935 - accuracy: 0.4977 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 19/50
# 63/63 [==============================] - 107s 2s/step - loss: 0.6929 - accuracy: 0.5269 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 20/50
# 63/63 [==============================] - 100s 2s/step - loss: 0.6934 - accuracy: 0.4777 - val_loss: 0.6931 - val_accuracy: 0.5010
# Epoch 21/50
# 63/63 [==============================] - 99s 2s/step - loss: 0.6961 - accuracy: 0.4877 - val_loss: 0.6942 - val_accuracy: 0.5000
# Epoch 22/50
# 63/63 [==============================] - 100s 2s/step - loss: 0.6930 - accuracy: 0.5329 - val_loss: 0.7412 - val_accuracy: 0.5000
# Epoch 23/50
# 63/63 [==============================] - 103s 2s/step - loss: 0.6905 - accuracy: 0.5272 - val_loss: 0.6706 - val_accuracy: 0.5990
# Epoch 24/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.6951 - accuracy: 0.5654 - val_loss: 0.6881 - val_accuracy: 0.5440
# Epoch 25/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.6864 - accuracy: 0.5715 - val_loss: 0.6896 - val_accuracy: 0.5510
# Epoch 26/50
# 63/63 [==============================] - 105s 2s/step - loss: 0.6858 - accuracy: 0.5622 - val_loss: 0.6799 - val_accuracy: 0.5510
# Epoch 27/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.6850 - accuracy: 0.5534 - val_loss: 0.7301 - val_accuracy: 0.5290
# Epoch 28/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.6803 - accuracy: 0.5721 - val_loss: 0.7528 - val_accuracy: 0.5090
# Epoch 29/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.6713 - accuracy: 0.5678 - val_loss: 0.8224 - val_accuracy: 0.5170
# Epoch 30/50
# 63/63 [==============================] - 106s 2s/step - loss: 0.6800 - accuracy: 0.5423 - val_loss: 0.7009 - val_accuracy: 0.5400
# Epoch 31/50
# 63/63 [==============================] - 107s 2s/step - loss: 0.6675 - accuracy: 0.5946 - val_loss: 0.6984 - val_accuracy: 0.5460
# Epoch 32/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.6583 - accuracy: 0.5974 - val_loss: 0.6955 - val_accuracy: 0.5430
# Epoch 33/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.6486 - accuracy: 0.6014 - val_loss: 0.7118 - val_accuracy: 0.5380
# Epoch 34/50
# 63/63 [==============================] - 98s 2s/step - loss: 0.6297 - accuracy: 0.6561 - val_loss: 0.6896 - val_accuracy: 0.5640
# Epoch 35/50
# 63/63 [==============================] - 92s 1s/step - loss: 0.6281 - accuracy: 0.6585 - val_loss: 0.6489 - val_accuracy: 0.6150
# Epoch 36/50
# 63/63 [==============================] - 100s 2s/step - loss: 0.5734 - accuracy: 0.6960 - val_loss: 0.6560 - val_accuracy: 0.6160
# Epoch 37/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.5690 - accuracy: 0.6933 - val_loss: 0.6837 - val_accuracy: 0.5640
# Epoch 38/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.5890 - accuracy: 0.6689 - val_loss: 0.6150 - val_accuracy: 0.6570
# Epoch 39/50
# 63/63 [==============================] - 98s 2s/step - loss: 0.5255 - accuracy: 0.7391 - val_loss: 0.6324 - val_accuracy: 0.6260
# Epoch 40/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.5084 - accuracy: 0.7327 - val_loss: 0.7003 - val_accuracy: 0.5440
# Epoch 41/50
# 63/63 [==============================] - 107s 2s/step - loss: 0.5117 - accuracy: 0.7386 - val_loss: 0.6379 - val_accuracy: 0.6280
# Epoch 42/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.4612 - accuracy: 0.7714 - val_loss: 0.6227 - val_accuracy: 0.6440
# Epoch 43/50
# 63/63 [==============================] - 105s 2s/step - loss: 0.4181 - accuracy: 0.8167 - val_loss: 0.6276 - val_accuracy: 0.6440
# Epoch 44/50
# 63/63 [==============================] - 104s 2s/step - loss: 0.3746 - accuracy: 0.8362 - val_loss: 0.6422 - val_accuracy: 0.6180
# Epoch 45/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.3529 - accuracy: 0.8459 - val_loss: 0.6554 - val_accuracy: 0.6520
# Epoch 46/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.2999 - accuracy: 0.8780 - val_loss: 0.6527 - val_accuracy: 0.6550
# Epoch 47/50
# 63/63 [==============================] - 102s 2s/step - loss: 0.2518 - accuracy: 0.8874 - val_loss: 0.6427 - val_accuracy: 0.6620
# Epoch 48/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.2009 - accuracy: 0.9235 - val_loss: 0.6682 - val_accuracy: 0.6570
# Epoch 49/50
# 63/63 [==============================] - 101s 2s/step - loss: 0.2080 - accuracy: 0.9123 - val_loss: 0.7775 - val_accuracy: 0.6180
# Epoch 50/50
# 63/63 [==============================] - 103s 2s/step - loss: 0.1909 - accuracy: 0.9235 - val_loss: 0.7929 - val_accuracy: 0.6540

# %%
# analysis
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# make a prediction for a new image.
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import matplotlib.image as mpimg

# load and prepare the image
def load_image(filename):
    # load the image
    img = load_img(filename, target_size=(224, 224))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 3 channels
    img = img.reshape(1, 224, 224, 3)
    # center pixel data
    img = img.astype('float32')
    img = img - [123.68, 116.779, 103.939]
    return img
 
# load an image and predict the class
def run_example():
    # load the image
    img = load_image('download.jpg')
    img_vir = mpimg.imread('download.jpg')
    imgplot = plt.imshow(img_vir)
    plt.show()
    # load model
   # model = load_model('final_model.h5')
    # predict the class
    result = model.predict(img)
    print(result)
 
# entry point, run the example
run_example()
# Out:
# [[1. 0.]]

# %%
def load_image(filename):
    # load the image
    img = load_img(filename, target_size=(224, 224))
    # convert to array
    img = img_to_array(img)
    # reshape into a single sample with 3 channels
    img = img.reshape(1, 224, 224, 3)
    # center pixel data
    img = img.astype('float32')
    img = img - [123.68, 116.779, 103.939]
    return img
 
# load an image and predict the class
def run_example():
    # load the image
    img = load_image('sample_image.jpg')
    img_vir = mpimg.imread('sample_image.jpg')
    imgplot = plt.imshow(img_vir)
    plt.show()
    # load model
   # model = load_model('final_model.h5')
    # predict the class
    result = model.predict(img)
    print(result)
 
# entry point, run the example
run_example()
# Out:
# [[0. 1.]]
